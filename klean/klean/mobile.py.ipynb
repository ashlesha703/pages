# %%
class Mobile:
    button = "on"
    call_list=[]
    ac_created = False
    is_login=False
    profile_pic=[]
    upload_post[]
def __init__(self,company,ROM,camera,RAM):
        self.company = company
        self.RAM = RAM
        self.ROM = ROM
        self.camera = camera
        
    def about (self):
        if self.button=="on":
            print("about Mobile")
            print("company :",self.company)
            print("RAM :",self.RAM)
            print("ROM :",self.ROM)
            print("camera :",self.camera)
        else:
            print("mobile locked")

    def call(self):
        from datetime.datetime import now
        import time
        if self.button=="on":
            number = input("dial number ...")
            Time= datetime.now()
            t=T.strftime("%d/%m/%y %H:%M%:S%")
            print("calling......".center(20," "))
            print(f"{number}".center(20," "))
            
            if input("is recieved? (y/n)")=="y":
                self.call_list.append(f"+{number} {t}")
               
            else:
                self.call_list.append(f"-{number} {t}")
                
        else:
            print("MobIle Locked")
        
    def unlock(self):
        if input("enter ur pin")== self.pin:
            print("unlocked")
            self.button = "on"
        else:
            print("WRONG PIN")
        
    def lock(self):
        print("locked")
        self.button = "off"
        
    def set_pin(self):
        self.pin = input("set your pin")
        print("pin registered")
    
    def call_details(self):
        for j,i in enumerate(self.call_list):
            print(j+1,":",i)
    
    def instagram(self):
        if self.iscreated_ac==False:
            print("sign up". center(17," "))
            self.username = input("username :")
            self.username = input("password :")
            print("account created🥳")
            self.iscreated_ac==True
        
        else:
            if self.is_login==False:
                uname=input("enter user name :")
                pword=input("enter password :")
                if self.username==uname and self.password==pword:
                    print("login successful")
                    self.is_login=True
                    self.insta_account()
                    
                else:
                    print("invalid login.")
        else:
            self.insta_account()
            
    def insta_account(self):
        import matplotlib.image as mping
        import matplotlib.pyplot as plt    
        if len(self.profile_plt)==0:
            img=input("image patch :")
            img=mpimg.imread(img_path)
            self.profile pic.append(img)
        else:
            print(f"{self,username}".center(20," "))
            
            plt.imshow(self.profile pic[0])
            plt.axis("off")
            plt.show()
            for i in self.uploaded_post:
                plt.figure(figuresize=(2,2))
                plt.imshow()
                plt.axis("off")
                plt.show()
  
   def change_profilepic(self):
        if self.iscreated_ac and self.is_login:
            import matplotlib.image as mpimg
            img_path = input("upload image :")
            img = mping.imread(img_path)
            self.profile_pic[0]=img :
                self.instagram()
        else:
            self.instagram()
            
    def post_upload(self):
        if self_iscreated_ac and self.is_login:
            import matplotlib.image as mpimg
            img_path = input("upload image :")
            img = mping.imread(img_path)
            self.upload_post.append(img)
            
        else:
            self.instagram()
# Out:
#   File "<tokenize>", line 96
#     def change_profilepic(self):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
ashlesha=Mobile("Real me","45GB","89GB","48MP")
ashlesha.about()
# Out:
# about Mobile
# company : Real me
# RAM : 48MP
# ROM : 45GB
# camera : 89GB
